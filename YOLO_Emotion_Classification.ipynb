# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("aklimarimi/8-facial-expressions-for-yolo")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 3.77G/3.77G [00:43<00:00, 93.2MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/aklimarimi/8-facial-expressions-for-yolo/versions/4

# %%
# !pip install ultralytics

# %%
import os

base = "/root/.cache/kagglehub/datasets/aklimarimi/8-facial-expressions-for-yolo/versions/4/9 Facial Expressions you need"
print(len(os.listdir(os.path.join(base, "train/images"))))
print(len(os.listdir(os.path.join(base, "train/labels"))))
# Out:
# 64864
# 64866

# %%
! yolo detect train \
  model=yolov8n.pt \
  data="/root/.cache/kagglehub/datasets/aklimarimi/8-facial-expressions-for-yolo/versions/4/9 Facial Expressions you need/data.yaml" \
  epochs=5 \
  imgsz=640 \
  batch=32 \
  device=0
# Out:
# Ultralytics 8.3.240 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !zip -r runs.zip runs
# Out:
#   adding: runs/ (stored 0%)
#   adding: runs/detect/ (stored 0%)
#   adding: runs/detect/train/ (stored 0%)
#   adding: runs/detect/train/labels.jpg (deflated 38%)
#   adding: runs/detect/train/args.yaml (deflated 51%)
#   adding: runs/detect/train/train_batch2.jpg (deflated 3%)
#   adding: runs/detect/train/weights/ (stored 0%)
#   adding: runs/detect/train/train_batch1.jpg (deflated 4%)
#   adding: runs/detect/train/train_batch0.jpg (deflated 4%)
#   adding: runs/detect/train2/ (stored 0%)
#   adding: runs/detect/train2/labels.jpg (deflated 38%)
#   adding: runs/detect/train2/val_batch1_labels.jpg (deflated 13%)
#   adding: runs/detect/train2/BoxF1_curve.png (deflated 5%)
#   adding: runs/detect/train2/val_batch1_pred.jpg (deflated 13%)
#   adding: runs/detect/train2/args.yaml (deflated 51%)
#   adding: runs/detect/train2/val_batch0_pred.jpg (deflated 10%)
#   adding: runs/detect/train2/BoxR_curve.png (deflated 5%)
#   adding: runs/detect/train2/BoxPR_curve.png (deflated 7%)
# ...

# %%
from google.colab import files
files.download("runs.zip")
